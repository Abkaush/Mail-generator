# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="openai/gpt-oss-120b"
)
response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to set foot on the Moon was **Neil Armstrong**, who did so on July 20 1969 during NASA’s Apollo 11 mission.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://careers.nike.com/lead-technology-asset-management/job/R-89188")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# C:\Users\Abakash\AppData\Local\Temp\ipykernel_12108\3069474278.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Lead Technology Asset Management
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
#
#
#
#
#
#
# Menu
#
#
#
# Return to Previous Menu
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Back to Search
#
#
#
# Lead Technology Asset Management
#
#
# Position Type
# Full Time
#
#
#
# Career area
# Technology Operations
#
#
# Location
# 1 Bowerman Drive, Beaverton, Oregon 97005, United States
#
#
#
# Job ID
# R-89188
#
#
#
#
#
#                                 Apply Now
#
#
#
#
#
#
#
# Share Job
#
#
#
#
# Share Job Posting
#
#
#
#
#
#
# Facebook
# Opens In A New Tab
#
#
#
#
#
#
#
# LinkedIn
# Link Opens In New Window
#
#
#
#
#
#
#
#
# Email
#
#
#
#
#
#
# Close-Medium (Default Size)-icon
#
# Close Menu
#
#
#
#
#
#
#
#
#
#
#
#
#
# Become a Part of the NIKE, Inc. Team
# NIKE, Inc. does more than outfit the world’s best athletes. It’s a place where passionate individuals come together to
#                         create the future of sport. We are unapologetic about who we are and what we’re after—bringing innovation and
#                         inspiration to every athlete* in the world. We look for athletes who can push boundaries, elevate our potential and
#                         continue leading us to greatness. The next tastemakers, playmakers, risk takers and glue players. Are you game?
#
# WHO WE ARE LOOKING FORWe’re seeking a detail-oriented and strategic Lead Technology Asset Manager to join our Global Technology organization. This role is critical in ensuring the lifecycle integrity of Nike’s global hardware and software assets. You will play a key role in driving operational excellence, compliance, and cost optimization across our asset estate.The ideal candidate is a collaborative leader who thrives in a fast-paced, global environment. You have a passion for asset management, strong analytical capabilities, and a track record of improving processes and implementing scalable asset lifecycle strategies. If you love solving complex problems, influencing change, and delivering value through data-driven decision-making, this role is for you.WHAT YOU WILL WORK ONAs a Lead Technology Asset Manager at Nike, you will:Lead end-to-end lifecycle management for Nike’s global assets—procurement, deployment, support, reclamation, and disposal.Maintain accurate asset data within ServiceNow HAM Pro, ServiceNow SAM Pro and the CMDB ensuring integrity, compliance, and reporting standards.Develop and enforce hardware asset management policies, standards, and processes aligned with ITIL and ISO standards.Partner with procurement, finance, service desk, and logistics teams to optimize asset utilization, reduce spend, and enable sustainability goals.Monitor key performance indicators (KPIs) to identify trends, risks, and opportunities for improvement.Support internal audits and ensure compliance with financial, security, and regulatory requirements.Collaborate with technology owners and site leads to manage inventories, refresh plans, and logistics across Nike’s global locations.Lead the implementation of automation and analytics tools to enhance asset visibility and decision-making.WHO YOU WILL WORK WITHThis role reports to the Director of Asset and Service Management and is part of the Global Technology CIS, Risk and Governance team. You’ll work cross-functionally with multiple teams and local site coordinators across Nike’s global footprint.WHAT YOU BRINGBachelor’s degree in information technology, Business, Supply Chain, or a related field; or equivalent combination of education and experience.5+ years of experience in IT Asset Management or related roles.Proven expertise in ServiceNow and other ITAM platforms.Strong knowledge of ITIL practices, ISO/IEC 19770 standards, and asset governance principles.Experience managing global inventories and logistics in a complex, matrixed organization.Excellent communication, stakeholder engagement, and analytical skills.Ability to influence cross-functional teams without direct authority.ServiceNow Certified Implementation Specialist – Hardware Asset ManagementITAM certifications (e.g., CHAMP, CSAM, CITAM)Experience supporting sustainability initiatives in asset lifecycle programsWe offer a number of accommodations to complete our interview process including screen readers, sign language interpreters, accessible and single location for in-person interviews, closed captioning, and other reasonable modifications as needed. If you discover, as you navigate our application process, that you need assistance or an accommodation due to a disability, please complete the Candidate Accommodation Request Form.
#
# NIKE, Inc. is a growth company that looks for team members to grow with it. Nike offers a
#                                 generous total rewards
#                                 package, casual work environment, a diverse and inclusive culture, and an electric
#                                 atmosphere for professional
#                                 development. No matter the location, or the role, every Nike employee shares one galvanizing
#                                 mission: To bring
#                                 inspiration and innovation to every athlete* in the world.
# NIKE, Inc. is an equal opportunity employer. Qualified applicants will receive
#                                 consideration without
#                                 regard to race, color, religion, sex, national origin, age, sexual orientation, gender
#                                 identity, gender expression,
#                                 veteran status, or disability.
#
#
#
#
#                                     Apply Now
#
#
#
#
#
#
#
# Share Job
#
#
#
#
# Share Job Posting
#
#
#
#
#
#
# Faceboox
# Opens In A New Tab
#
#
#
#
#
#
#
# LinkedIn
# Link Opens In New Window
#
#
#
#
#
#
#
#
# Email
#
#
#
#
#
#
# Close-Medium (Default Size)-icon
#
# Close Menu
#
#
#
#
#
#
#
#
#
#
#
# What You Can Expect
# OUR HIRING GAME PLAN
#
#
# 01 Apply
# Our teams are made up of diverse skillsets, knowledge bases, inputs, ideas and backgrounds.
#                                 We want you to find your fit – review job descriptions, departments and teams to discover
#                                 the role for you.
#
#
# 02 Meet a Recruiter or Take an Assessment
# If selected for a corporate role, a recruiter will reach out to start your interview process
#                                 and be your main contact
#                                 throughout the process. For retail roles, you’ll complete an interactive assessment that
#                                 includes a chat and quizzes and
#                                 takes about 10-20 minutes to complete.  No matter the role, we want to learn about you – the
#                                 whole you – so don’t shy
#                                 away from how you approach world-class service and what makes you unique.
#
#
# 03 Interview
# Go into this stage confident by doing your research, understanding what we are looking for
#                                 and being prepared for
#                                 questions that are set up to learn more about you, and your background.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# About Us
#
#
# Contact
#
#
# Talent Community
#
#
# Terms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Nike Applicant Privacy Policy
#
#
#
#
#
#
# We offer a number of accommodations to complete our interview process including screen readers, sign language interpreters,
#                 accessible and single location for in-person interviews, closed captioning, and other reasonable modifications as
#                 needed.
#
#
# If you discover, as you navigate our application process, that you need assistance or an accommodation due to a
#                 disability, please contact us at +1 503-671-4156 and include your full name, best way to reach you, and the
#                 accommodation you request to assist with the application process.
# For more information, please refer to Equal Employment
#                         Opportunity is The Law.
#
#
#
# ©  Nike, Inc. All Rights Reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
# Chat
# Chat with our AI Assistant

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Lead Technology Asset Management',
#  'experience': '5+ years of experience in IT Asset Management or related roles',
#  'skills': ['ServiceNow HAM Pro',
#   'ServiceNow SAM Pro',
#   'CMDB management',
#   'ITIL practices',
#   'ISO/IEC 19770 standards',
#   'Asset governance principles',
#   'Global inventory and logistics management',
#   'Stakeholder engagement',
#   'Analytical and data‑driven decision making',
#   'Cross‑functional influence without direct authority',
#   'ServiceNow Certified Implementation Specialist – Hardware Asset Management',
#   'ITAM certifications (CHAMP, CSAM, CITAM)',
#   'Sustainability initiatives in asset lifecycle programs'],
#  'description': 'Nike is seeking a detail‑oriented and strategic Lead Technology Asset Manager to join the Global Technology organization. The role is responsible for end‑to‑end lifecycle management of Nike’s global hardware and software assets, including procurement, deployment, support, reclamation, and disposal. The incumbent will maintain accurate asset data in ServiceNow HAM Pro, SAM Pro, and the CMDB, develop and enforce asset management policies aligned with ITIL and ISO standards, partner with procurement, finance, service desk, and logistics to optimize utilization and reduce spend, monitor KPIs, support audits, and lead automation and analytics initiatives. The position reports to the Director of Asset and Service Management and works cross‑functionally across Nike’s global footprint.'}

# %%
type(json_res)
# Out:
# dict

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
pip install onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in .\venv\Lib\site-packages (1.28.0)
# Requirement already satisfied: flatbuffers in .\venv\Lib\site-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in .\venv\Lib\site-packages (from onnxruntime) (2.5.2)
# Requirement already satisfied: packaging in .\venv\Lib\site-packages (from onnxruntime) (26.3)
# Requirement already satisfied: protobuf>=4.25.8 in .\venv\Lib\site-packages (from onnxruntime) (7.35.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
job = json_res
job['skills']
# Out:
# ['ServiceNow HAM Pro',
#  'ServiceNow SAM Pro',
#  'CMDB management',
#  'ITIL practices',
#  'ISO/IEC 19770 standards',
#  'Asset governance principles',
#  'Global inventory and logistics management',
#  'Stakeholder engagement',
#  'Analytical and data‑driven decision making',
#  'Cross‑functional influence without direct authority',
#  'ServiceNow Certified Implementation Specialist – Hardware Asset Management',
#  'ITAM certifications (CHAMP, CSAM, CITAM)',
#  'Sustainability initiatives in asset lifecycle programs']

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/xamarin-portfolio'},
#   {'links': 'https://example.com/java-portfolio'}],
#  [{'links': 'https://example.com/java-portfolio'},
#   {'links': 'https://example.com/kotlin-android-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
#   {'links': 'https://example.com/kotlin-backend-portfolio'}],
#  [{'links': 'https://example.com/java-portfolio'},
#   {'links': 'https://example.com/android-tv-portfolio'}],
#  [{'links': 'https://example.com/typescript-frontend-portfolio'},
#   {'links': 'https://example.com/angular-portfolio'}],
#  [{'links': 'https://example.com/typescript-frontend-portfolio'},
#   {'links': 'https://example.com/devops-portfolio'}],
#  [{'links': 'https://example.com/devops-portfolio'},
#   {'links': 'https://example.com/xamarin-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/xamarin-portfolio'},
#   {'links': 'https://example.com/typescript-frontend-portfolio'}],
#  [{'links': 'https://example.com/kotlin-backend-portfolio'},
#   {'links': 'https://example.com/xamarin-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/ios-portfolio'}],
#  [{'links': 'https://example.com/kotlin-backend-portfolio'},
#   {'links': 'https://example.com/vue-portfolio'}]]

# %%
job
# Out:
# {'role': 'Lead Technology Asset Management',
#  'experience': '5+ years of experience in IT Asset Management or related roles',
#  'skills': ['ServiceNow HAM Pro',
#   'ServiceNow SAM Pro',
#   'CMDB management',
#   'ITIL practices',
#   'ISO/IEC 19770 standards',
#   'Asset governance principles',
#   'Global inventory and logistics management',
#   'Stakeholder engagement',
#   'Analytical and data‑driven decision making',
#   'Cross‑functional influence without direct authority',
#   'ServiceNow Certified Implementation Specialist – Hardware Asset Management',
#   'ITAM certifications (CHAMP, CSAM, CITAM)',
#   'Sustainability initiatives in asset lifecycle programs'],
#  'description': 'Nike is seeking a detail‑oriented and strategic Lead Technology Asset Manager to join the Global Technology organization. The role is responsible for end‑to‑end lifecycle management of Nike’s global hardware and software assets, including procurement, deployment, support, reclamation, and disposal. The incumbent will maintain accurate asset data in ServiceNow HAM Pro, SAM Pro, and the CMDB, develop and enforce asset management policies aligned with ITIL and ISO standards, partner with procurement, finance, service desk, and logistics to optimize utilization and reduce spend, monitor KPIs, support audits, and lead automation and analytics initiatives. The position reports to the Director of Asset and Service Management and works cross‑functionally across Nike’s global footprint.'}

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at Infosys. Infosys is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of Infosys 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Infosys's portfolio: {link_list}
        Remember you are Mohan, BDE at Infosys. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# **Subject:** Accelerating Nike’s Global Technology Asset Management with Infosys Expertise
#
# Hi [Hiring Manager’s Name],
#
# I’m Mohan, Business Development Executive at Infosys. We specialize in AI‑driven, end‑to‑end IT Asset Management solutions that align perfectly with Nike’s vision for a strategic, data‑centric Lead Technology Asset Manager.
#
# **Why Infosys is the ideal partner for Nike**
#
# - **ServiceNow HAM & SAM Mastery** – Our certified consultants have delivered large‑scale ServiceNow Hardware Asset Management (HAM) and Software Asset Management (SAM) implementations for Fortune 500 enterprises, automating asset discovery, lifecycle tracking, and compliance reporting while integrating tightly with the CMDB.
# - **ITIL & ISO 19770 Compliance** – We embed ITIL best practices and ISO/IEC 19770 standards into governance frameworks, ensuring audit‑ready asset data, robust policy enforcement, and continuous improvement.
# - **Global Inventory & Logistics Optimization** – Leveraging AI‑powered analytics, we help clients consolidate global inventories, streamline logistics, and achieve up to 30 % reduction in total cost of ownership.
# - **Cross‑Functional Influence & Automation** – Our DevOps and RPA capabilities enable seamless collaboration across procurement, finance, service desk, and logistics without the need for direct authority, delivering real‑time dashboards and automated workflows.
# - **Sustainability & Circular Economy** – We embed sustainability metrics into asset lifecycle programs, supporting responsible reclamation and disposal aligned with Nike’s ESG goals.
#
# **Relevant Infosys Portfolio Highlights**
#
# - **Enterprise‑grade ServiceNow & DevOps Automation** – https://example.com/devops-portfolio
# - **AI‑driven Analytics & ML for Asset Optimization** – https://example.com/ml-python-portfolio
# - **Scalable Java‑based Backend Platforms** – https://example.com/java-portfolio
# - **Modern Front‑end & TypeScript Solutions** – https://example.com/typescript-frontend-portfolio
#
# These case studies demonstrate our ability to build robust, secure, and scalable asset management ecosystems that drive measurable ROI.
#
# I would welcome a brief call to explore how Infosys can help Nike achieve faster, more accurate asset governance, cost savings, and sustainability outcomes. Please let me know a convenient time next week, or feel free to book directly on my calendar [insert calendar link].
#
# Thank you for considering a partnership that can elevate Nike’s technology asset strategy.
#
# Best regards,
# Mohan Kumar
# Business Development Executive – Infosys
# Phone: +1 (555) 123‑4567
# Email: mohan.kumar@infosys.com
# LinkedIn: linkedin.com/in/mohan‑kumar‑infosys
